# %%
import pandas as pd
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import numpy as np
#Additional Data Processing

df=pd.read_excel('BPR Only .xlsx')
df['Status']=df['Status'].astype('category').cat.codes
df['    BusA']=df['    BusA'].astype('category').cat.codes
df['CCAr']=df['CCAr'].astype('category').cat.codes
#df['Account']=df['Account'].astype('category').cat.codes
df.drop(columns='Reference',inplace=True)
df.drop(columns='Customer Name',inplace=True)
df.drop(columns=['DocumentNo','Month','Year','Clrng doc.'],inplace=True)
df['Zone']=df['Zone'].astype('category').cat.codes
df['Bran']=df['Bran'].astype('category').cat.codes
df['PayT'] = df['PayT'].astype('category').cat.codes
df.drop(columns='Doc/Chq dt',inplace=True)
df['Pstng Date']=df['Pstng Date'].dt.strftime("%Y%m%d").astype(str)
df['Net Due Dt']=df['Net Due Dt'].dt.strftime("%Y%m%d").astype(str)
df['Clearing']=df['Clearing'].dt.strftime("%Y%m%d").astype(str)
#data.sort_values("Name", axis = 0, ascending = True,
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Status'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-4214c7c91757> in <module>
#       6
#       7 df=pd.read_excel('BPR Only .xlsx')
# ----> 8 df['Status']=df['Status'].astype('category').cat.codes
#       9 df['    BusA']=df['    BusA'].astype('category').cat.codes
#      10 df['CCAr']=df['CCAr'].astype('category').cat.codes
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Status'

# %%
df
# Out:
#                          Unnamed: 0        Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                               NaN               NaN         NaN         NaN
# 1                        Row Labels  Count of Account         NaN         NaN
# 2                    AADINATH STEEL        0.00173658         NaN         NaN
# 3               AASHRAY ENTERPRISES        0.00103003         NaN         NaN
# 4          AHLADA ENGINEERS LIMITED       0.000161741         NaN         NaN
# 5        AHLADA ENGINEERS PVT. LTD.        2.5538e-05         NaN         NaN
# 6                AMIT IRON PVT. LTD         0.0191705         NaN         NaN
# 7                  ANISH ENTERPRISE        0.00104706         NaN         NaN
# 8                 ANM ISPAT PVT LTD         0.0122497         NaN         NaN
# 9     ASHOK HARDWARE AND STEEL MART        0.00111516         NaN         NaN
# 10            B K STEEL ENTERPRISES         0.0116198         NaN         NaN
# 11              B ODHAVJI & COMPANY        0.00217924         NaN         NaN
# 12           B.K. STEEL ENTERPRISES       5.95887e-05         NaN         NaN
# 13    B.ODHAVJI  AND COMPANY RETAIL        0.00342209         NaN         NaN
# 14            B.ODHAVJI AND COMPANY       0.000612912         NaN         NaN
# 15   BAJRANG STEEL (SALES) CORPORAT          0.004367         NaN         NaN
# 16                  BANSAL BROTHERS        0.00572051         NaN         NaN
# 17    BAZARI STEELS PRIVATE LIMITED       0.000417121         NaN         NaN
# 18             BHAGWATI STEEL SALES         0.0136969         NaN         NaN
# 19   BHARTIA  DISTRIBUTORS PVT. LTD        0.00185576         NaN         NaN
# 20               BIHANI ENTERPRISES        0.00502247         NaN         NaN
# 21    BIHANI INTERNATIONAL PVT LTD.       0.000289431         NaN         NaN
# 22               BIRMA INDUSTRIAL &        0.00390731         NaN         NaN
# 23                 BMW VENTURES LTD        0.00680162         NaN         NaN
# 24                BMW VENTURES LTD.         0.0323992         NaN         NaN
# 25       BMW VYAPAR PRIVATE LIMITED        0.00173658         NaN         NaN
# 26             BODHAVJI AND COMPANY         0.0014131         NaN         NaN
# 27             BUBNA COMMERCIAL CO.        0.00770396         NaN         NaN
# 28         BUBNA COMMERCIAL PVT LTD       0.000459684         NaN         NaN
# 29            COLLATE STEEL PVT LTD        0.00105557         NaN         NaN
# ..                              ...               ...         ...         ...
# 107            SHIVA FERRIC PVT LTD        0.00732089         NaN         NaN
# 108        SHREE SAI KRISHNA STEELS        0.00175361         NaN         NaN
# 109               SHRI RAM MULTICOM         0.0113304         NaN         NaN
# 110                  SHRI RAM SALES        0.00827431         NaN         NaN
# 111     SILIGURI BUILDERS PVT. LTD.        0.00978105         NaN         NaN
# 112  SILVER STAR COMMOTRADE PRIVATE       0.000655475         NaN         NaN
# 113                       SKM GALVA         0.0107089         NaN         NaN
# 114  SKM STEELS LIMITED(CRCADIVISIO         0.0286962         NaN         NaN
# 115                  SKM STEELS LTD        0.00966188         NaN         NaN
# 116  SKM STEELS LTD (CRCA DIVISION)       0.000919368         NaN         NaN
# 117  SKM STEELS LTD. (TISCON-TMT DI        0.00140459         NaN         NaN
# 118          SM CORPORATION LIMITED          0.014114         NaN         NaN
# 119         SM CORPORATION LTD (BV)       8.51267e-05         NaN         NaN
# 120         SM CORPORATION LTD (LA)       6.81013e-05         NaN         NaN
# 121  SM CORPORATION LTD (PRAVESH_LA       8.51267e-06         NaN         NaN
# 122        SRI BALAJI STEEL TRADERS         0.0120369         NaN         NaN
# 123     SUDISA ENTERPRISES (P) LTD.        0.00142162         NaN         NaN
# 124           TATA STEEL PROCESSING         0.0707828         NaN         NaN
# 125         TEJRAM RAMNIWAS AGARWAL        0.00664839         NaN         NaN
# 126  THE INDIAN MINERAL CO ( RETAIL         0.0071251         NaN         NaN
# 127               THIRUPATHY STEELS        0.00689526         NaN         NaN
# 128       TIKMANI STEEL TRADING CO.        0.00665691         NaN         NaN
# 129     TIRUPATI BALAJI ENTERPRISES       0.000153228         NaN         NaN
# 130       V.N.C. STEEL DISTRIBUTORS         0.0253763         NaN         NaN
# 131         VATIKA TRACOM PVT. LTD.        0.00687823         NaN         NaN
# 132   VIJAY SHEETS & STRIPS (P) LTD       0.000212817         NaN         NaN
# 133  VIJAY SHEETS AND STRIPS PVT LT        0.00259636         NaN         NaN
# 134    VIKRANT IRON PRIVATE LIMITED         0.0107004         NaN         NaN
# 135   WRINKLE DISTRIBUTORS PVT LTD.        0.00323481         NaN         NaN
# 136                     Grand Total                 1         NaN         NaN
#
#      Unnamed: 4  Unnamed: 5                      Row Labels  Count of Account
# 0           NaN         NaN           TATA STEEL PROCESSING          0.070783
# 1           NaN         NaN                     Rohit & Co.          0.039950
# 2           NaN         NaN  NARESH STEEL INDUSTRIES PVT. L          0.035166
# 3           NaN         NaN               BMW VENTURES LTD.          0.032399
# 4           NaN         NaN  SKM STEELS LIMITED(CRCADIVISIO          0.028696
# 5           NaN         NaN       V.N.C. STEEL DISTRIBUTORS          0.025376
# 6           NaN         NaN    SAMRAT IRONS PRIVATE LIMITED          0.023103
# 7           NaN         NaN                    SAGAR STEELS          0.020984
# 8           NaN         NaN              AMIT IRON PVT. LTD          0.019171
# 9           NaN         NaN  ORISSA SMALL INDUSTRIES CORPOR          0.019102
# 10          NaN         NaN           FERRO STEEL SOLUTIONS          0.019034
# 11          NaN         NaN        PASA RESOURCES PVT. LTD.          0.018404
# 12          NaN         NaN  NORTHERN STEEL AND GENERAL MIL          0.017885
# 13          NaN         NaN      SANGEETA STEEL CORPORATION          0.017374
# 14          NaN         NaN        M/S.DHARAMVIR & BROTHERS          0.016055
# 15          NaN         NaN                   RAKESH STEELS          0.014335
# 16          NaN         NaN                G R GUPTA & BROS          0.014250
# 17          NaN         NaN          SM CORPORATION LIMITED          0.014114
# 18          NaN         NaN            BHAGWATI STEEL SALES          0.013697
# 19          NaN         NaN  SANJEEV INDUSTRIAL CORPORATION          0.012565
# 20          NaN         NaN       DELHI TRADING CORPORATION          0.012446
# 21          NaN         NaN               ANM ISPAT PVT LTD          0.012250
# 22          NaN         NaN        SRI BALAJI STEEL TRADERS          0.012037
# 23          NaN         NaN        FAIRDEAL STEELS PVT.LTD.          0.011730
# 24          NaN         NaN           B K STEEL ENTERPRISES          0.011620
# 25          NaN         NaN     KISHAN LAL PAWAN KUMAR JAIN          0.011458
# 26          NaN         NaN               SHRI RAM MULTICOM          0.011330
# 27          NaN         NaN             G.K.ISPAT PVT. LTD.          0.010990
# 28          NaN         NaN                     MANGLA SONS          0.010871
# 29          NaN         NaN                       SKM GALVA          0.010709
# ..          ...         ...                             ...               ...
# 107         NaN         NaN                 M/S SHREE SALES          0.000945
# 108         NaN         NaN  SKM STEELS LTD (CRCA DIVISION)          0.000919
# 109         NaN         NaN                  SADASHIV STEEL          0.000758
# 110         NaN         NaN  KRISHNA TRADERS (SHEET DIVISIO          0.000741
# 111         NaN         NaN  SILVER STAR COMMOTRADE PRIVATE          0.000655
# 112         NaN         NaN           B.ODHAVJI AND COMPANY          0.000613
# 113         NaN         NaN                   EMPIRE STEELS          0.000553
# 114         NaN         NaN            FAIRDEAL ENTERPRISES          0.000545
# 115         NaN         NaN       G K ISPAT PRIVATE LIMITED          0.000468
# 116         NaN         NaN        BUBNA COMMERCIAL PVT LTD          0.000460
# 117         NaN         NaN   BAZARI STEELS PRIVATE LIMITED          0.000417
# 118         NaN         NaN  DSM STEEL AND WIRES PRIVATE LI          0.000409
# 119         NaN         NaN   BIHANI INTERNATIONAL PVT LTD.          0.000289
# 120         NaN         NaN                   PREM BROTHERS          0.000247
# 121         NaN         NaN         MODERN DISTROPOLIS LTD.          0.000221
# 122         NaN         NaN   VIJAY SHEETS & STRIPS (P) LTD          0.000213
# 123         NaN         NaN                M/S. MANGLA SONS          0.000187
# 124         NaN         NaN  RIMO STEEL REFORMS PRIVATE LIM          0.000170
# 125         NaN         NaN        AHLADA ENGINEERS LIMITED          0.000162
# 126         NaN         NaN     TIRUPATI BALAJI ENTERPRISES          0.000153
# 127         NaN         NaN         SM CORPORATION LTD (BV)          0.000085
# 128         NaN         NaN         SM CORPORATION LTD (LA)          0.000068
# 129         NaN         NaN          B.K. STEEL ENTERPRISES          0.000060
# 130         NaN         NaN  NSSPL INDUSTRIES PRIVATE LIMIT          0.000060
# 131         NaN         NaN      AHLADA ENGINEERS PVT. LTD.          0.000026
# 132         NaN         NaN                   HIND AGENCIES          0.000026
# 133         NaN         NaN  SM CORPORATION LTD (PRAVESH_LA          0.000009
# 134         NaN         NaN                             NaN               NaN
# 135         NaN         NaN                             NaN               NaN
# 136         NaN         NaN                             NaN               NaN
#
# [137 rows x 8 columns]

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('RAW1.xlsx')

# %%
df.shape
# Out:
# (5382, 22)

# %%
df.head()
# Out:
#    Material No Matl Group MG 1 MG 2 MG 3  WidthXThk   PROFILE  \
# 0      1232975       DOOR  DIN  SIS  SLF   915X2057  100 X 58
# 1      1208180  STEELDOOR  DIN  WIS  SLF   915X2057  100 X 58
# 2      1232973       DOOR  DIN  SIS  SLF  1067X2057  100 X 58
# 3      1278232  STEELDOOR  DEX  EES  SLF  1067X2057  100 X 58
# 4      1232976       DOOR  DIN  SIS  SLF   915X2057  100 X 58
#
#    SHEET THICKNESS  FRAME THICKNESS  SHUTTER THICKNESS  ...  LOCK MAKE  \
# 0              0.8              1.2                 46  ...     Dorset
# 1              0.8              1.2                 46  ...     Dorset
# 2              0.8              1.2                 46  ...     Dorset
# 3              0.8              1.2                 46  ...  Dorset-KT
# 4              0.8              1.2                 46  ...     Dorset
#
#        Design Peephole SP_FEAT                      Material Description  \
# 0  PLAINSTEEL       No    F001          PLAIN STEEL DOOR915 X 2057LHOSIS
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
df.drop(columns=['SHUTTER THICKNESS','SHEET THICKNESS'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-173-f3e3f04f9ebb> in <module>
#       1
# ----> 2 df.drop(columns=['SHUTTER THICKNESS','SHEET THICKNESS'],inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
df.shape
# Out:
# (5382, 20)

# %%
df.head()
# Out:
#    Material No Matl Group MG 1 MG 2 MG 3  WidthXThk   PROFILE    COLOUR  \
# 0      1232975       DOOR  DIN  SIS  SLF   915X2057  100 X 58  RAL 8017
# 1      1208180  STEELDOOR  DIN  WIS  SLF   915X2057  100 X 58   R-02-01
# 2      1232973       DOOR  DIN  SIS  SLF  1067X2057  100 X 58  RAL 8017
# 3      1278232  STEELDOOR  DEX  EES  SLF  1067X2057  100 X 58   R-02-01
# 4      1232976       DOOR  DIN  SIS  SLF   915X2057  100 X 58  RAL 8017
#
#    LOCK MAKE      Design                      Material Description  \
# 0     Dorset  PLAINSTEEL          PLAIN STEEL DOOR915 X 2057LHOSIS
# 1     Dorset         NaN             STEELDOORWOOD FINISH915 X2057
# 2     Dorset  PLAINSTEEL         PLAIN STEEL DOOR1067 X 2057RHOSIS
# 3  Dorset-KT         E32  EMB STEEL DOOR WOODFIN EXT 1067 X 2057MM
# 4     Dorset  PLAINSTEEL          PLAIN STEEL DOOR915 X 2057RHOSIS
#
#    Order Qty (No of Doors)  No. of Orders  No. of Months  No. of Distributors  \
# ...

# %%
df.dropna(axis=1,inplace=True)

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators = 100,
                           n_jobs = -1,
                           oob_score = True,
                           bootstrap = True,
                           random_state = 42)

# %%
rf
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#            oob_score=True, random_state=42, verbose=0, warm_start=False)

# %%
df['WidthXThk']=df.WidthXThk.astype("category").cat.codes

# %%
df.head()
# Out:
#    Material No Matl Group MG 1 MG 2 MG 3  WidthXThk  PROFILE    COLOUR  \
# 0      1232975       DOOR  DIN  SIS  SLF        776        0  RAL 8017
# 1      1208180  STEELDOOR  DIN  WIS  SLF        776        0   R-02-01
# 2      1232973       DOOR  DIN  SIS  SLF        175        0  RAL 8017
# 3      1278232  STEELDOOR  DEX  EES  SLF        175        0   R-02-01
# 4      1232976       DOOR  DIN  SIS  SLF        776        0  RAL 8017
#
#    LOCK MAKE      Design                      Material Description  \
# 0     Dorset  PLAINSTEEL          PLAIN STEEL DOOR915 X 2057LHOSIS
# 1     Dorset         NaN             STEELDOORWOOD FINISH915 X2057
# 2     Dorset  PLAINSTEEL         PLAIN STEEL DOOR1067 X 2057RHOSIS
# 3  Dorset-KT         E32  EMB STEEL DOOR WOODFIN EXT 1067 X 2057MM
# 4     Dorset  PLAINSTEEL          PLAIN STEEL DOOR915 X 2057RHOSIS
#
#    Order Qty (No of Doors)  No. of Orders  No. of Months  No. of Distributors  \
# ...

# %%
df['LOCK MAKE']=df['LOCK MAKE'].astype("category").cat.codes

# %%
df = df.drop(["Order Qty (No of Doors)", "No. of Months", "No. of Distributors"], axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-99-6d9d54ec1be5> in <module>
# ----> 1 df = df.drop(["Order Qty (No of Doors)", "No. of Months", "No. of Distributors"], axis=1,inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
df.shape[0]
# Out:
# 5382

# %%
df.to_csv('DATA.csv')

# %%
df1=read

# %%
df=pd.read_excel('RAW1.xlsx')

# %%
np.random.seed(20)
y=np.random.rand(df.shape[0],1)

# %%
rf.fit(df,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-172-bbd619715a50> in <module>
# ----> 1 rf.fit(df,y)
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     248
#     249         # Validate or convert input data
# --> 250         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     251         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     252         if sample_weight is not None:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
#     526                 warnings.simplefilter('error', ComplexWarning)
# ...

# %%
df1=df[['Order Qty (No of Doors)','No. of Orders','No. of Months','No. of Distributors','No. of Regions']]

# %%
df1
# Out:
#       Order Qty (No of Doors)  No. of Orders  No. of Months  \
# 0                          87             38              9
# 1                          50             33              9
# 2                          68             26              9
# 3                          56             21              9
# 4                          71             29              8
# 5                          53             20              8
# 6                          46             14              8
# 7                          15             14              8
# 8                          52             25              8
# 9                          42             27              8
# 10                         17             11              8
# 11                        143             20              8
# 12                        143             24              8
# 13                         85             28              8
# 14                         67             27              8
# ...

# %%
np.random.seed(2000)
y=np.random.randint(low=0, high=50, size=(df1.shape[0],1))
y
# Out:
# array([[ 8],
#        [14],
#        [13],
#        ...,
#        [42],
#        [35],
#        [35]])

# %%
rf.fit(df1,y)
# Out:
# C:\Users\Laptop\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#            oob_score=True, random_state=42, verbose=0, warm_start=False)

# %%
rf.score(df1, y)
# Out:
# 0.08923615121039075

# %%
feature_importances = pd.DataFrame(rf.feature_importances_,
                                   index = df1.columns,
                                    columns=['importance']).sort_values('importance',ascending=False)

# %%
feature_importances
# Out:
#                          importance
# Order Qty (No of Doors)    0.390449
# No. of Orders              0.239356
# No. of Months              0.164397
# No. of Distributors        0.135599
# No. of Regions             0.070199

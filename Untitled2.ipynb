# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_excel('PAYMENT.xlsx')

# %%
#df["INVOICE DATE"] = pd.to_datetime(df["INVOICE DATE"]).dt.strftime("%Y%m%d")
#df["CLEARING DATE"] = pd.to_datetime(df["CLEARING DATE"]).dt.strftime("%Y%m%d")

# %%
df['Difference'] = df['CLEARING DATE'].sub(df['INVOICE DATE'], axis=0)

# %%
df['Difference']=df['Difference']/np.timedelta64(1,'D')#.apply(pd.to_numeric)

# %%
df
# Out:
#     INVOICE DATE    AMOUNT CLEARING DATE  POD  Difference
# 0     2019-01-28  0.567728    2019-02-11    9        14.0
# 1     2018-11-25  0.701253    2018-12-09    5        14.0
# 2     2018-07-09  0.560119    2018-07-09    7         0.0
# 3     2018-06-20  0.683401    2018-07-01    5        11.0
# 4     2018-06-03  0.429630    2018-06-03    7         0.0
# 5     2018-04-06  0.666492    2018-04-12    3         6.0
# 6     2018-10-17  0.146306    2018-11-04    8        18.0
# 7     2018-08-27  0.480846    2018-08-30    0         3.0
# 8     2019-02-16  0.103945    2019-02-20    2         4.0
# 9     2018-12-30  0.971608    2019-01-05    8         6.0
# 10    2018-06-29  0.868946    2018-07-15    9        16.0
# 11    2018-08-12  0.505994    2018-08-17   10         5.0
# 12    2018-06-04  0.823545    2018-06-24    4        20.0
# 13    2018-09-13  0.276738    2018-10-01    5        18.0
# 14    2018-08-22  0.947360    2018-08-25    9         3.0
# ...

# %%
arr=[]
for i in range(len(df)):
    if(df['Difference'][i]-df['POD'][i]>15):
        arr.append(0)
    elif(df['Difference'][i]-df['POD'][i]>10):
        arr.append(1)
    elif(df['Difference'][i]-df['POD'][i]>5):
        arr.append(2)
    else:
        arr.append(3)
#df['label']=arr

# %%
len(df)
# Out:
# 199

# %%
df["INVOICE DATE"] = pd.to_datetime(df["INVOICE DATE"]).dt.strftime("%Y%m%d")
df["CLEARING DATE"] = pd.to_datetime(df["CLEARING DATE"]).dt.strftime("%Y%m%d")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CLEARING DATE'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-d51b4bf461bc> in <module>
# ...

# %%
df.drop(columns=['CLEARING DATE'],inplace=True)
df.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-fc8033163951> in <module>
# ----> 1 df.drop(columns=['CLEARING DATE'],inplace=True)
#       2 df.shape
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
from sklearn.model_selection import train_test_split
xTrain, xTest,yTrain,yTest = train_test_split(df,arr)

# %%
from sklearn.cluster import KMeans

# %%
xTrain.shape
# Out:
# (149, 4)

# %%
kmeans = KMeans(n_clusters=4)  
y=kmeans.fit_predict( xTrain,  sample_weight=None)
print (metrics.accuracy_score(yTrain, y))
# Out:
# 0.2751677852348993

# %%
from sklearn import metrics
pred=kmeans.predict(xTest)
print (metrics.accuracy_score(yTest, pred))
# Out:
# 0.24

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-480051cfeccb> in <module>
# ----> 1 xTest[1,:-1]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#    2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# ...

# %%
arr=['>15 days','10-15 days','5-10 days','0-5 days']

# %%
#for i in range(len(df)):
 #   df['cluster_label'][i]=arr[df['cluster_label'][i]]

# %%
date=int(input("Enter date in yyyymmdd:"))
pod=int(input("POD:"))

# %%
kmeans.predict([date])

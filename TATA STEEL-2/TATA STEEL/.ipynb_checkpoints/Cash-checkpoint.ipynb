# %%
import pandas as pd
import numpy as np
from pmdarima.arima import auto_arima
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import time

# %%
df1=pd.read_csv('MyData.csv')
df1=df1[df1['Sale.Type']=='Cash']
df2=df1[['Pstng.Date','Account','Local.Crcy.Amt']]
df2.index=pd.to_datetime(df1['Pstng.Date'])
df=df2#pd.read_csv('CashData.csv',  parse_dates = ['Pstng.Date'], index_col=1)
df.drop(columns='Pstng.Date',inplace=True)
print('Total Number of Unique Customers = ',len(np.unique(df['Account'])))
# Out:
# Total Number of Unique Customers =  138

# %%
dic={}
def cash(df,date,offset_days,offset_count):
    unique_customer=np.unique(df['Account'])
    df=df.sort_index()
    out=unique_customer
    for cust in unique_customer[:5]:
        df_targets=df[df['Account'] == cust]
        #print(df_targets.head())
        df_targets.drop(columns='Account',inplace=True)
        train=df_targets[df_targets.index <= pd.to_datetime(date,format='%Y%m%d') ]
        train=train.groupby(train.index,as_index=True).mean()
        valid=df_targets[df_targets.index >= pd.to_datetime(date,format='%Y%m%d') ]
        valid=valid.groupby(valid.index,as_index=True).mean()
        if(len(train)<2):
            print()
            print('NO TRANSACTIONS EXPECTED FROM THIS CUSTOMER ',cust)
            print()
            print('Moving on...')
            print('---------------------------------------------------------------------------------------------------')
            continue
            
        d=pd.to_datetime(date,format='%Y%m%d')-pd.to_timedelta(offset_days, unit='D') 
        if(len(train[train.index > pd.to_datetime(d,format='%Y%m%d')]) < offset_count):
            print()
            print('NO TRANSACTIONS EXPECTED FROM THIS CUSTOMER ',cust)
            print()
            print('Moving on...')
            print('---------------------------------------------------------------------------------------------------')
            continue
        #, error_action='ignore'
        
        if(len(valid)<3):
            print()
            print('NO TRANSACTIONS EXPECTED FROM THIS CUSTOMER ',cust)
            print()
            print('Moving on...')
            print('---------------------------------------------------------------------------------------------------')
            continue
            
        grp=train.groupby(train.index).size().reset_index().rename(columns={0:'records'})
        day=pd.to_datetime(date,format='%Y%m%d')-pd.to_timedelta(5,unit='D')
        grp=grp[grp['Pstng.Date'] >= day]
        count=grp['records'].mean()
        print('Average_count= ',count)
        
        
        model = auto_arima(np.exp(train), trace=True,error_action='warn',n_iter=10,n_jobs=-1,solver='newton')
        model.fit(train)
        forecast = model.predict(n_periods=len(valid))
        if(count==0):
            count=1
        
        dic.update({cust:forecast*count})
        
        forecast = pd.DataFrame(forecast,index = valid.index,columns=['Prediction'])
        
        #print(forecast.head())
        
        plt.title(cust)
        plt.plot(np.exp(train), label='Train')
        plt.plot(np.exp(valid),label='Valid')
        plt.plot(np.exp(forecast), label='Prediction')
        plt.show()

        print('----------------------------------------------------------------------------------------------------------')

# %%
date=20181101
offset_days=60
offset_count=5
cash(df,date,offset_days,offset_count)
out=pd.DataFrame.from_dict(dic,orient='index')
out.to_csv('output_cash.csv')
# Out:
# Average_count=  1.0
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 0, 0, 1); AIC=-423.600, BIC=-409.159, Fit time=0.331 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 0, 1); AIC=-433.110, BIC=-428.296, Fit time=0.050 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 0, 1); AIC=-431.233, BIC=-424.013, Fit time=0.225 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 0, 1); AIC=-431.219, BIC=-423.999, Fit time=0.084 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 0, 0, 1); AIC=-429.174, BIC=-419.548, Fit time=0.178 seconds
# Total fit time: 0.877 seconds
# ----------------------------------------------------------------------------------------------------------
# Average_count=  1.0
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 0, 0, 1); AIC=-531.048, BIC=-513.441, Fit time=0.972 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 0, 0, 1); AIC=-489.570, BIC=-483.701, Fit time=0.146 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 0, 0, 1); AIC=-514.724, BIC=-505.921, Fit time=0.632 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 0, 0, 1); AIC=-529.491, BIC=-520.688, Fit time=0.576 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 0, 0, 1); AIC=-525.401, BIC=-510.729, Fit time=0.691 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(0, 0, 0, 1); AIC=-528.175, BIC=-507.634, Fit time=2.028 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(0, 0, 0, 1); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 0, 0, 1); AIC=-524.802, BIC=-504.260, Fit time=2.449 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 0, 0, 1); AIC=-531.805, BIC=-520.067, Fit time=1.088 seconds
# Total fit time: 8.598 seconds
# ----------------------------------------------------------------------------------------------------------
#
# NO TRANSACTIONS EXPECTED FROM THIS CUSTOMER  100879
#
# Moving on...
# ---------------------------------------------------------------------------------------------------
#
# NO TRANSACTIONS EXPECTED FROM THIS CUSTOMER  100922
#
# Moving on...
# ---------------------------------------------------------------------------------------------------
# Average_count=  1.0
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 0, 0, 1); AIC=-960.719, BIC=-941.662, Fit time=0.917 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 0, 0, 1); AIC=-863.712, BIC=-857.359, Fit time=0.074 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 0, 0, 1); AIC=-895.740, BIC=-886.212, Fit time=0.407 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 0, 0, 1); AIC=-963.182, BIC=-953.653, Fit time=0.444 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 0, 0, 1); AIC=-961.551, BIC=-948.847, Fit time=0.853 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 0, 0, 1); AIC=-959.914, BIC=-947.209, Fit time=0.480 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 0, 0, 1); AIC=-961.635, BIC=-945.755, Fit time=0.629 seconds
# Total fit time: 3.815 seconds
# ----------------------------------------------------------------------------------------------------------

# %%
out
# Out:
#               0         1         2         3         4         5         6   \
# 100237  0.139906  0.139906  0.139906  0.139906  0.139906  0.139906  0.139906
# 100789  0.239595  0.228637  0.226472  0.226220  0.226383  0.226637  0.226910
# 100985  0.160347  0.160357  0.160366  0.160376  0.160386  0.160395  0.160405
#
#               7         8         9   ...        45        46        47  \
# 100237  0.139906  0.139906  0.139906  ...       NaN       NaN       NaN
# 100789  0.227188  0.227466  0.227745  ...  0.237782  0.238061  0.238340
# 100985  0.160415  0.160424  0.160434  ...  0.160783  0.160792  0.160802
#
#               48        49        50        51        52       53       54
# 100237       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 100789       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 100985  0.160812  0.160821  0.160831  0.160841  0.160851  0.16086  0.16087
#
# [3 rows x 55 columns]
